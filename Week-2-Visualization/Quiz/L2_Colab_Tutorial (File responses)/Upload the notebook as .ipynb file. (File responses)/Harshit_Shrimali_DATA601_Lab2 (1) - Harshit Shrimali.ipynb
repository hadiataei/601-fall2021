# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

nba_players = pd.read_csv('https://raw.githubusercontent.com/msaricaumbc/DS601_Fall21/main/Week02/data/all_seasons.csv', index_col = 0)

height = nba_players['player_height']
points = nba_players['pts']

plt.title('Height Graph')
axes = plt.gca()
axes.set_xlim([155,240])
plt.xticks(np.arange(155, 240, 10.0))
plt.hist(nba_players.player_height, width=5)
plt.xlabel('Height')
plt.ylabel('Number of Players')
# Out:
# Text(0, 0.5, 'Number of Players')

# %%
plt.title('Points Graph')
axes = plt.gca()
axes.set_xlim([0,35])
plt.xticks(np.arange(0, 35,2.5))
plt.hist(nba_players.pts,width=3)
plt.xlabel('Points')
plt.ylabel('Number of Players')
# Out:
# Text(0, 0.5, 'Number of Players')

# %%
plt.title('NBA players Height vs Points')
plt.scatter(nba_players.player_height, nba_players.pts)
plt.xlabel('Height')
plt.ylabel('Points')
# Out:
# Text(0, 0.5, 'Points')

# %%
bowling_data = pd.read_csv("https://raw.githubusercontent.com/msaricaumbc/DS601_Fall21/main/Week02/data/bowling_stats.csv",
                            header=None,
                            names=['year','city','state','count1','count2'])
def merge_columns(row):
    if pd.isna(row['count2']):
        return row['count1']
    else:
        return row['count1']*1000+row['count2']
    
bowling_data['total']=bowling_data.apply(merge_columns,axis=1)

year = bowling_data['year']
score = bowling_data['total']
f = plt.subplots(1, figsize=(100,10))
plt.title('Year Vs Score Graph')
plt.plot(year,score)
plt.xlabel('Year')
plt.ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')
