# %% [markdown]
# ## Homework 2
#
# Please complete the functions below. These functions are for to simulate a fair and a biased die.
#
# The biased die has probabilities {0.25, 0.15, 0.15, 0.15, 0.15, 0.15}.
#
# Create 2 visualizations that shows outcomes of multiple rolls of a fair die and biased die.
# * Visualization for fair die
# * Visualization for biased die
#
# Repeat the process programatically and take the mean to create a new list. This list will be used to compare means of biased & unbiased dice.
# * Create a historgram showing means of biased & unbiased die
#
# * Use subcharts
# * All visualizations must have appropriate titles.
# * There are 3 visualization and expected format is
# ```
#  [V1] [V2]
#  [   V3  ]
#  ```

# %%
import random 
import matplotlib.pyplot as plt

trial_count = 500
def fair_die_simulation():
    
    #returns an array of randomly numbers between 1 and 6. 
    options = [1,2,3,4,5,6]
    simulations_fair = [random.choices(options,k = trial_count)]
    return simulations_fair

def makehisto_fair():
  occurances=fair_die_simulation()
  plt.hist(occurances,6)
makehisto_fair()

# %%
import random 
import matplotlib.pyplot as plt

trial_count = 500
weights=[0.25, 0.15, 0.15, 0.15, 0.15, 0.15]

def biased_die_simuation():
    """
    returns an array of randomly numbers between 1 and 6 with the probabilty of assosiated weight. 
    for instance: for weights: [0.25, 0.15, 0.15, 0.15, 0.15, 0.15]
    1 has 0.25 change to be selected, 2 has 0.15 chance and so on...
    """
    
    options = [1,2,3,4,5,6]
    simulations_bias = [random.choices(options,weights,k=trial_count)]
    return simulations_bias

def makehisto():
  occurances=biased_die_simuation()
  plt.hist(occurances,6)
makehisto()

# %%
import random 
import matplotlib.pyplot as plt
from statistics import mean

trial_count = 500
weights=[0.25, 0.15, 0.15, 0.15, 0.15, 0.15]

#Bias Die Functions
def biased_die_simuation():
    """
    returns an array of randomly numbers between 1 and 6 with the probabilty of assosiated weight. 
    for instance: for weights: [0.25, 0.15, 0.15, 0.15, 0.15, 0.15]
    1 has 0.25 change to be selected, 2 has 0.15 chance and so on...
    """
    
    options = [1,2,3,4,5,6]
    simulations_bias = [random.choices(options,weights,k=trial_count)]
    return simulations_bias

def makehisto_bias():
  occurances_bias=biased_die_simuation()
  #plt.hist(occurances_bias,6)
  return occurances_bias
  makehisto_bias()

#Fair Die Functions
def fair_die_simulation():
    
    #returns an array of randomly numbers between 1 and 6. 
    options = [1,2,3,4,5,6]
    simulations_fair = [random.choices(options,k = trial_count)]
    return simulations_fair

def makehisto_fair():
  occurances_fair=fair_die_simulation()
  #plt.hist(occurances_fair,6)
  return occurances_fair
  makehisto_fair()

def makemeans():
  occurances_fair = makehisto_fair()
  occurances_bias = makehisto_bias()
  biasmean=mean(occurances_bias)
  fairmean=mean(orrurances_fair)
  makemeans()


plt.figure()
occurances_fair = makehisto_fair()
occurances_bias = makehisto_bias()
plt.subplot(3,4,1)
plt.hist(occurances_fair,6)
plt.xlabel('Side of Dice')
plt.ylabel('Occurances')
plt.title('Fair Die Occurances by Side') 

plt.subplot(3,4,4)
plt.hist(occurances_bias,6)
plt.xlabel('Side of Dice')
plt.ylabel('Occurances')
plt.title('Biased Die Occurances by Side')

plt.subplot(3,4,(10,11))
plt.hist(occurances_bias,6,color='red')
plt.hist(occurances_fair,6,color='yellow', alpha=.5)
plt.xlabel('Side of Dice')
plt.ylabel('Occurances')
plt.title('Bias and Fair Die Overlay')
plt.show() 
"""
I wasn't sure how to make a histogram of only 
two mean values, so I made an overlay 
of the histograms
"""
# Out:
# "\nI wasn't sure how to make a histogram of only \ntwo mean values, so I made an overlay \nof the histograms\n"

# %%
# !ls
# Out:
# sample_data

# %%
cd ..
# Out:
# /
