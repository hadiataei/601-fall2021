# %% [markdown]
# ## Homework 2
#
# Please complete the functions below. These functions are for to simulate a fair and a biased die.
#
# The biased die has probabilities {0.25, 0.15, 0.15, 0.15, 0.15, 0.15}.
#
# Create 2 visualizations that shows outcomes of multiple rolls of a fair die and biased die.
# * Visualization for fair die
# * Visualization for biased die
#
# Repeat the process programatically and take the mean to create a new list. This list will be used to compare means of biased & unbiased dice.
# * Create a historgram showing means of biased & unbiased die
#
# * Use subcharts
# * All visualizations must have appropriate titles.
# * There are 3 visualization and expected format is
# ```
#  [V1] [V2]
#  [   V3  ]
#  ```

# %%
import random 
import matplotlib.pyplot as plt

trial_count = 500

def fair_die_simulation(trials):
    """
    returns an array of randomly numbers between 1 and 6. 
    
    """
    simulations = []
    for i in range(trials):
      p = random.randrange(1,7)
      simulations.append(p)
    
    #options = [1,2,3,4,5,6]
    
    return simulations

# %%
#Trial
check_simulation = fair_die_simulation(trial_count)
print(check_simulation)
# Out:
# [5, 5, 6, 1, 3, 6, 5, 5, 3, 5, 2, 6, 2, 4, 2, 1, 2, 1, 2, 6, 6, 5, 3, 5, 2, 4, 4, 3, 3, 1, 3, 5, 3, 3, 4, 5, 6, 3, 6, 1, 5, 6, 5, 2, 3, 4, 2, 3, 3, 1, 4, 1, 2, 1, 4, 6, 1, 6, 6, 2, 3, 1, 2, 2, 6, 4, 5, 4, 3, 6, 2, 5, 2, 4, 6, 5, 4, 2, 6, 2, 3, 3, 4, 6, 1, 5, 3, 3, 3, 1, 6, 3, 6, 2, 6, 2, 4, 5, 4, 4, 4, 1, 4, 5, 3, 4, 4, 1, 3, 4, 2, 1, 4, 4, 2, 4, 4, 6, 5, 1, 4, 3, 4, 2, 4, 6, 3, 2, 5, 4, 2, 2, 2, 4, 4, 5, 1, 5, 2, 2, 3, 3, 6, 6, 4, 5, 6, 1, 5, 3, 4, 1, 2, 6, 5, 6, 4, 2, 5, 6, 4, 4, 1, 6, 5, 3, 2, 5, 2, 1, 5, 2, 1, 6, 3, 4, 2, 4, 2, 1, 5, 4, 5, 1, 1, 2, 4, 6, 2, 5, 1, 1, 3, 3, 6, 3, 4, 5, 4, 2, 5, 4, 6, 5, 6, 2, 1, 2, 4, 6, 5, 6, 4, 2, 6, 6, 4, 4, 6, 5, 3, 4, 1, 4, 5, 6, 5, 3, 1, 6, 2, 2, 1, 2, 1, 5, 4, 5, 3, 6, 6, 1, 3, 3, 5, 5, 2, 3, 4, 3, 3, 1, 6, 1, 1, 1, 3, 3, 2, 6, 4, 6, 3, 5, 6, 4, 2, 3, 6, 1, 2, 2, 5, 1, 3, 4, 5, 4, 1, 4, 6, 5, 1, 5, 6, 5, 3, 1, 5, 2, 3, 2, 3, 2, 6, 4, 5, 6, 4, 2, 4, 5, 6, 6, 5, 1, 1, 2, 1, 4, 2, 3, 3, 1, 5, 4, 3, 4, 1, 2, 3, 2, 3, 6, 3, 1, 5, 6, 3, 2, 3, 4, 5, 6, 4, 1, 4, 1, 3, 6, 3, 5, 2, 6, 3, 6, 3, 3, 3, 1, 3, 1, 6, 6, 1, 2, 3, 2, 4, 6, 3, 4, 3, 5, 6, 6, 2, 3, 4, 2, 1, 6, 6, 2, 3, 2, 4, 6, 4, 3, 3, 2, 6, 3, 6, 4, 6, 4, 5, 5, 4, 4, 3, 5, 4, 3, 3, 6, 4, 6, 3, 4, 2, 4, 4, 1, 4, 1, 3, 1, 5, 4, 5, 2, 
# [105, 73, 78, 95, 65, 84]

# %%
#Graphical representaiton of number of times each number was found
plt.bar([1,2,3,4,5,6],value_counts)
# Out:
# <BarContainer object of 6 artists>

# %%
#plt.hist(simulations, bins=range(min(simulations),max(simulations)))
plt.hist(simulations, bins=range(min(simulations),max(simulations)))
# Out:
# (array([105.,  73.,  78., 160.]),
#  array([1, 2, 3, 4, 5]),
#  <a list of 4 Patch objects>)

# %%
plt.pie(value_counts,labels=[1,2,3,4,5,6])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f899f273910>,
#   <matplotlib.patches.Wedge at 0x7f899f0f29d0>,
#   <matplotlib.patches.Wedge at 0x7f899f0b9310>,
#   <matplotlib.patches.Wedge at 0x7f899f0c5ad0>,
#   <matplotlib.patches.Wedge at 0x7f899f212f50>,
#   <matplotlib.patches.Wedge at 0x7f899f132050>],
#  [Text(0.8691705275003083, 0.6741977411151984, '1'),
#   Text(-0.22644881804572115, 1.0764390056132749, '2'),
#   Text(-1.0067652701313383, 0.44319712415286916, '3'),
#   Text(-0.8606299203692174, -0.6850665224379854, '4'),
#   Text(0.11727219924988325, -1.0937308769908143, '5'),
#   Text(0.9503157109862053, -0.5539856040122192, '6')])

# %%
def biased_die_simuations(trials, weights=[0.25, 0.15, 0.15, 0.15, 0.15, 0.15]):
    """
    returns an array of randomly numbers between 1 and 6 with the probabilty of assosiated weight. 
    for instance: for weights: [0.25, 0.15, 0.15, 0.15, 0.15, 0.15]
    1 has 0.25 change to be selected, 2 has 0.15 chance and so on...
    """
    simulations = []
    #for i in range(trials):
    i = 0
    while i < trials:
      randRoll = random.random()
      
      sum = 0
      if randRoll<weights[0]:
        result = 1
        i+=1
        simulations.append(result)
        continue
      elif randRoll<weights[0] + weights[1]: #  0.25 < randRoll <0.4

        result = 2
        i+=1
        simulations.append(result)
        continue
      elif randRoll<weights[0]+weights[1]+weights[2]: # 0.4<randRoll<0.55
        result = 3
        i+=1
        simulations.append(result)
        continue
      elif randRoll<weights[0]+weights[1]+weights[2]+weights[3]: #0.55<  < 0.7
        result = 4
        i+=1
        simulations.append(result)
        continue
      elif randRoll<weights[0]+weights[1]+weights[2]+weights[3]+weights[4]: #0.7 <    < 0.85
        result = 5
        i+=1
        simulations.append(result)
        continue
      else:
        result = 6
        simulations.append(result) 
        continue
      
    
    options = [1,2,3,4,5,6]
    
    return simulations

# %%
biased_simulations = biased_die_simuations(trial_count,[0.25, 0.15, 0.15, 0.15, 0.15, 0.15])
print(biased_simulations)
# Out:
# [1, 1, 2, 5, 5, 5, 3, 6, 1, 5, 2, 3, 3, 3, 1, 4, 1, 6, 2, 1, 1, 6, 2, 6, 4, 2, 2, 5, 2, 1, 6, 6, 3, 3, 1, 5, 1, 2, 5, 1, 2, 6, 6, 1, 1, 4, 4, 1, 5, 3, 1, 2, 3, 3, 4, 1, 1, 6, 2, 1, 1, 6, 2, 2, 1, 3, 5, 4, 1, 3, 1, 6, 1, 1, 3, 1, 1, 2, 6, 4, 5, 3, 2, 3, 2, 1, 2, 6, 1, 1, 6, 6, 4, 4, 1, 6, 4, 4, 1, 3, 1, 5, 2, 6, 2, 6, 5, 3, 3, 5, 3, 4, 6, 1, 5, 2, 4, 2, 3, 4, 5, 1, 1, 6, 4, 6, 2, 2, 6, 5, 3, 6, 1, 1, 5, 4, 4, 1, 1, 1, 4, 1, 3, 2, 5, 5, 1, 6, 6, 1, 6, 5, 3, 3, 2, 6, 3, 2, 4, 6, 3, 1, 4, 3, 6, 2, 1, 4, 1, 5, 4, 1, 1, 4, 2, 3, 6, 6, 4, 2, 6, 3, 3, 2, 4, 5, 1, 3, 4, 5, 4, 2, 5, 1, 3, 1, 3, 5, 4, 2, 2, 5, 2, 1, 1, 1, 1, 3, 6, 5, 6, 4, 3, 1, 2, 3, 6, 2, 1, 3, 4, 1, 6, 5, 1, 2, 5, 6, 1, 4, 1, 3, 4, 6, 5, 4, 5, 1, 3, 5, 4, 2, 6, 5, 1, 1, 1, 1, 1, 1, 3, 5, 5, 1, 4, 3, 1, 3, 3, 1, 1, 4, 6, 3, 3, 6, 3, 6, 1, 1, 2, 1, 2, 2, 5, 5, 2, 2, 1, 1, 5, 1, 5, 3, 5, 1, 6, 6, 5, 1, 1, 6, 6, 3, 5, 6, 4, 1, 1, 4, 1, 3, 5, 6, 1, 1, 4, 3, 1, 5, 3, 2, 2, 5, 4, 5, 6, 2, 1, 1, 3, 6, 1, 1, 4, 2, 6, 3, 2, 6, 4, 2, 3, 2, 4, 6, 5, 5, 3, 6, 2, 4, 3, 3, 6, 2, 2, 1, 2, 3, 1, 4, 1, 1, 1, 2, 2, 5, 3, 3, 1, 1, 6, 4, 3, 1, 1, 6, 1, 3, 6, 1, 5, 5, 5, 1, 2, 2, 2, 6, 3, 2, 4, 2, 2, 5, 1, 3, 6, 6, 5, 1, 4, 1, 1, 4, 3, 4, 2, 5, 1, 5, 1, 1, 3, 4, 4, 3, 1, 1, 4, 6, 3, 3, 2, 5, 6, 3, 3, 4, 4, 1, 5, 6, 5, 6, 3, 4, 5, 5, 5, 1, 1, 6, 1, 2, 6, 6, 2, 6, 2, 4, 1, 4, 6, 1, 3, 4, 5, 5, 1, 2, 1, 3, 4, 3, 2, 1, 1, 1, 1, 5, 3, 2, 4, 5, 5, 1, 3, 5, 6, 3, 5, 5, 6, 1, 6, 2, 1, 1, 6, 1, 2, 4, 6, 2, 1, 3, 3, 6, 3, 4, 5, 5, 5, 3, 1, 3, 5, 5, 2, 5, 4, 2, 3, 1, 1, 4, 1, 3, 1, 1, 4, 5, 6, 2, 5, 1, 1, 5, 4, 1, 3, 2, 2, 5, 1, 1, 1, 1, 1, 3, 2, 4, 3, 1, 1, 3, 1, 2, 5, 1, 1, 2, 5, 1, 2, 1, 5, 6, 1, 5, 2, 1, 2, 6, 2, 1, 1, 5, 1, 3, 1, 1, 1, 1, 4, 2, 5, 4, 5, 4, 5, 5, 4, 3, 6, 2, 1, 5]

# %%
biased_simulations = biased_die_simuations(trial_count,[0.20, 0.075, 0.075, 0.075, 0.075, 0.50])
biased_value_counts = []
for i in range(6):
  biased_value_counts.append(biased_simulations.count(i+1))
plt.bar([1,2,3,4,5,6],biased_value_counts)
# Out:
# <BarContainer object of 6 artists>

# %%
biased = biased_die_simuations(trial_count)
fair = fair_die_simulation(trial_count)

# biased_mean_list = ...
# unbiased_mean_list = ...

# %%
biased_simulations.count(3)
# Out:
# 0

# %%
biased_simulations

# %%
random.random()
# Out:
# 0.2739375336903491

# %%
random.randrange(1,10)
# Out:
# 8
