# %% [markdown]
# # Before Class
#
# - Identify three articles as the reading material and assign it to class beforehand.
#
#
# # Lecture Materials
#
# - For the hands-on part, we need an interesting dataset and some tasks focused on practicing course objectives.
# - Do we want to cover object-oriented api too in this class?
# - We can identify 5 most important best practices in visualization and focus on these.
# - We should decide whether we would like to cover seaborn in this lecture or not. If yes then materials should be added.
#
# # After Class:
#
# - We can create a quiz with some questions
#
# - Also we need to prepare an assignment for this class.
