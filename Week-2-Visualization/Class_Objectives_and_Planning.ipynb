# %% [markdown]
# # Visualization with Python - Course Objectives

# %% [markdown]
# ## Tools
#
# - Matplotlib
#
#   - focus on pyplot interface
#   - creating plots and changing style
#   - Adding title, labels etc.
#   - plotting with keyword strings
#   - working with multiple figures and axes
#   - annotating figures
#
# - Seaborn

# %% [markdown]
# ## Concepts

# %% [markdown]
# - Distinguishing bad and good practices in data visualization.
#
# - Histograms and box plots for statistical distributions.

# %% [markdown]
# Resources to use:

# %% [markdown]
# [Graphic Lies, Misleading Visuals](https://d18ky98rnyall9.cloudfront.net/7yQEXL8gR8ykBFy_ILfMbg_8b3084c2d72342b9bb885f988fca5a27_BookChapterLIES.pdf?Expires=1628812800&Signature=Tz4C6XlNMA~gks~oDKOcZsEmCf66a4SwIn5h5AX99tdofuPzvU8g6z2Or75xY9GUdoGU86XssDczkLP6S9gpre5T5qfi1YYLKHdOtAAkfpHIPris-nsfDV0bb-QHU0-EvAV6NtQsRWKIKc0UpuhcsUGiyvf5R7jJiwFLVSxiZ1Y_&Key-Pair-Id=APKAJLTNE6QMUY6HBC5A)
#
# [Coursera: Applied Plotting](https://www.coursera.org/learn/python-plotting/home/welcome): You don't have to pay to enroll you can audit and get the most of the content.
#
# [Alberto Cairo - Data Visualization: Reasons not rules](https://harvard.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=cb8f5389-f453-431c-8fc8-ac3d00e1ddaf)
#
# [Useful Junk? The effects of visual embellishment on comprehension and memorability of charts](https://www.researchgate.net/publication/221517808_Useful_Junk_The_effects_of_visual_embellishment_on_comprehension_and_memorability_of_charts)
#
# [Some examples of good visualizations: Darkhorse Analytics](https://www.darkhorseanalytics.com/portfolio-all/
# )
#
# [Box Plot - Wiki](https://en.wikipedia.org/wiki/Box_plot)
#
# [Tukey : Exploratory data analysis](https://archive.org/details/exploratorydataa00tuke_0)
#
# [matplotlib - tutorials](https://matplotlib.org/stable/tutorials/index.html)
#
# [matplotlib tutorials - pyplot interface](https://matplotlib.org/stable/tutorials/introductory/pyplot.html)
#
# [matplotlib - annotations](https://matplotlib.org/stable/tutorials/text/annotations.html#plotting-guide-annotation)
