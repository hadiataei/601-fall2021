# %%
from datetime import date
print('Author: Murat Guner')
print('Last_Updated on: ', date.today())
# Out:
# Author: Murat Guner
# Last_Updated on:  2021-08-30

# %% [markdown]
# Here, I'm recording some of the resources I used as I prepared these materials. Please feel free to add more. Make sure that you give a brief explanation why you liked the added resource.

# %% [markdown]
# # Relevant Books and Chapters

# %% [markdown]
# [Principles of Data Science - Chapter - I](https://drive.google.com/file/d/1GuhpIk7gFmiVSUhWmqC7s29JlqxqrXkD/view?usp=sharing)
#
# [Introducing Data Science:](https://drive.google.com/file/d/1tVgwLIY1ab6yIZX4qC2dwpjGkqQhXBfm/view?usp=sharing)
#
# - 1.1 -- Big Data, use cases of big data
#
# - 1.2 -- Types of data: Structured, unstructured, machine generated, graph-based etc. and their brief description.
#
# - 1.3 -- Data Science Process.
#
# - p 11: A nice graph of big data ecosystem and interaction of different technologies.
#
# [Managing Data Science Effective Strategies to Manage Data Science Projects and Build A Sustainable Team](https://drive.google.com/file/d/1B1evx_6ioXLmE0W3irla8oLQMiH75uOm/view?usp=sharing)
#
# - p9: AI-ML-Deep Learning and data science Venn Diagram.
#
# - p10-11: Influence of data science and its limitations
#
# - p100: General flow of how roles can work together to build the final solution.
# - p101: Description of common data roles in an organization.
# - p102-p107: Case Studies to discuss the roles in a data science team.
# - p106: Key skills of a data scientist
#
#
# [Think Like a Data Scientist](https://drive.google.com/file/d/1iHU1JnITdmABM8mXzI_SqsgyuPlBfgxG/view?usp=sharing)
#
# - p4: 'What ... think data science is' cartoon.
#
# - p6: Data Science Process: 'Prepare --> Build --> Iterate' figure.
#
# - p9: 1.3: Developer vs data scientist more concrete.
#
# - p10: Does a data scientist need to be a software developer?
#
# - p11: Does a data scientist need to know statistics?
#
# - p14: Best practices

# %% [markdown]
# # Online Articles and Resources

# %% [markdown]
# [Data-8:This text was originally developed for the UC Berkeley course Data 8: Foundations of Data Science.](https://inferentialthinking.com/chapters/01/2/why-data-science.html)
