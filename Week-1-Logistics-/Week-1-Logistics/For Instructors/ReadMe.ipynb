# %%
from datetime import date
print('Author: Murat Guner')
print('Last_Updated on: ', date.today())
# Out:
# Author: Murat Guner
# Last_Updated on:  2021-08-30

# %% [markdown]
# - Double check the links, paths and the code and make sure that they are up-to-date.
#
# - In part-III of the notebook, as part of the lab, there is a quiz linked. However this quiz is mostly for to make sure that students can use Colab and submit their work for later assignments.
