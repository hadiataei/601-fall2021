# %%
from datetime import date
print('Author: Hadi Ataei')
print('Last_Updated on: ', date.today())
# Out:
# Author: Murat Guner
# Last_Updated on:  2021-08-30

# %% [markdown]
# # Course Objectives for Week-I

# %% [markdown]
# ## Logistics
#
# - Discuss class rules, resources, expectations.
#
# - Discuss assignments and late submission policy.

# %% [markdown]
# ## Introduction to Data Science
#
# - Give an overview of data science field. Discuss basic definitions and roles.
#
# - Emphasize on different phases of data science project.

# %% [markdown]
# ## Tools
#
# - Use of notebooks, markdown.
#
# - Basic terminal commands: ls, cd, mkdir, touch etc. To keep things simple, we can teach these via google colab again.
#
# - Running a python script.
#
# - Very basic level review of Python. Also communicate the expectation with respect to Python programming. Mention resources and choices if a student feels they are not ready for the class.
