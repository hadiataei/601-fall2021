# %% [markdown]
# # Before Class
#
# - Choose three articles to be read before the class.
#
#
# # Lecture Materials
#
# - Add a hands-on part with some instructions parallel to what we covered in the class.
#
# # After Class
#
# - Prepare a quiz with some questions parallel to the teaching objectives.
