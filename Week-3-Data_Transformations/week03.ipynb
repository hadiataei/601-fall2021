# %% [markdown]
# # Part-I:

# %% [markdown]
# ## Pandas

# %%
# install pandas

# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %% [markdown]
# [For more on installation](https://pandas.pydata.org/pandas-docs/stable/getting_started/install.html)

# %%
import pandas as pd

pd.__version__
# Out:
# '1.1.5'

# %% [markdown]
# # Pandas object
# Basically, Pandas object can be identified as an enhanced version of NumPy structured arrays where columns and rows are identified with labels instead of integer indices.

# %% [markdown]
# __Basic data structures in Pandas:__
#
# - DataFrames
#
# - Series
#
# [Why to have more than one data structures](https://pandas.pydata.org/pandas-docs/stable/getting_started/overview.html#why-more-than-one-data-structure)

# %% [markdown]
# ### Series
#
# A pandas series is a one dimensional of indexed data. It can be created from a list or array

# %%
data = pd.Series([0.1,0.2,0.9,0.7,0.5,0.8])

# %%
data
# Out:
# 0    0.1
# 1    0.2
# 2    0.9
# 3    0.7
# 4    0.5
# 5    0.8
# dtype: float64

# %%
# create a list of car makes
cars = ['Toyota', 'Honda', 'Toyota', 'Kia', 'Honda', 'GMC', 'Kia', 'Mazda', 'Hyundai', 'Mazda']

# dir(cars)

# %% [markdown]
# Note that the 'cars' is a 'list' object.

# %%
# create a series from cars list
series_cars = pd.Series(cars, name= "Cars", index = [1,3,5,7,13, 15, 17, 1,2,3] )
# let's take a look at series_cars
series_cars
# Out:
# 1      Toyota
# 3       Honda
# 5      Toyota
# 7         Kia
# 13      Honda
# 15        GMC
# 17        Kia
# 1       Mazda
# 2     Hyundai
# 3       Mazda
# Name: Cars, dtype: object

# %%
series_cars[3]
# Out:
# 3    Honda
# 3    Mazda
# Name: Cars, dtype: object

# %% [markdown]
# - Discuss index, name and differences of lists and series
#  - An index is an array-like object of type pd.index.
#  - Like with a NumPy array data can be accessed by the associated index via the familiar Python square-bracket notation.

# %%
series_cars.index
# Out:
# Int64Index([1, 3, 5, 7, 13, 15, 17, 1, 2, 3], dtype='int64')

# %%
series_cars[1]
# Out:
# 1    Toyota
# 1     Mazda
# Name: Cars, dtype: object

# %%
series_cars[0:2]
# Out:
# 1    Toyota
# 3     Honda
# Name: Cars, dtype: object

# %% [markdown]
# ## Series vs. generalized NumPy Array
#
# The essential difference is the presence of the index: while the NumPy array has an implicitly defined integer index used to access the values, the Pandas Series has an explicitly defined index associated with the values.

# %%
data = pd.Series([0.25,0.5,0.75,1],index=['a','b','c','c'])

# %%
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# c    1.00
# dtype: float64

# %%
data['b']

# %% [markdown]
# ## Series as specialized Python Dictionary
# So, we can consider Pandas Series a bit like a specialization of a Python dictionary. A dictionary is a structure that maps arbitrary keys to a set of arbitrary values, and a Series is a structure that maps typed keys to a set of types values.
#
# Being typed make it more efficient that general dictionary.
#
# We can make a Series directly from dictionary.

# %%
population_dict = {'California':38000000,'Texas':26000000,'New York':19000000,'Florida':19000000,'Illinois':12000000}
population = pd.Series(population_dict)
population
# Out:
# California    38000000
# Texas         26000000
# New York      19000000
# Florida       19000000
# Illinois      12000000
# dtype: int64

# %%
# unlike a dictionary  Series supports array-style operations such as slicing:
population['California':'Illinois']
# Out:
# California    38000000
# Texas         26000000
# New York      19000000
# Florida       19000000
# Illinois      12000000
# dtype: int64

# %%
#Construction  series
pd.series(data,index=index)

# %%
pd.Series([2,4,6])
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
pd.Series(5,index=[100,200,300])

# %%
#data can be dictionary in which index defaults to the sorted idctionary keys
pd.Series({2:'a',1:'b',3:'c'})

# %%
#Index can be explicitly set if a different result is prefered
pd.Series({2:'a',1:'b', 3:'c'},index=[3,2])

# %% [markdown]
# Like the Series object, the DataFrame has an index attribute that gives access to the index labels:

# %%
states.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %%
states.columns
# Out:
# Index(['population', 'area'], dtype='object')

# %%
## P

# %%
series_cars.iloc[3]
# Out:
# 'Kia'

# %%
series_cars.loc[3]
# Out:
# 3    Honda
# 3    Mazda
# Name: Cars, dtype: object

# %% [markdown]
# - Discuss the benefits of series over other data structures by showing methods designed for handling tabular data like, value_counts, sort_index, sort_values, etc

# %%
series_cars.sort_index()
# Out:
# 1      Toyota
# 1       Mazda
# 2     Hyundai
# 3       Honda
# 3       Mazda
# 5      Toyota
# 7         Kia
# 13      Honda
# 15        GMC
# 17        Kia
# Name: Cars, dtype: object

# %%
series_cars.sort_values()
# Out:
# 15        GMC
# 3       Honda
# 13      Honda
# 2     Hyundai
# 7         Kia
# 17        Kia
# 1       Mazda
# 3       Mazda
# 1      Toyota
# 5      Toyota
# Name: Cars, dtype: object

# %%
series_cars.value_counts()
# Out:
# Kia        2
# Honda      2
# Mazda      2
# Toyota     2
# GMC        1
# Hyundai    1
# Name: Cars, dtype: int64

# %%
series_cars.values
# Out:
# array(['Toyota', 'Honda', 'Toyota', 'Kia', 'Honda', 'GMC', 'Kia', 'Mazda',
#        'Hyundai', 'Mazda'], dtype=object)

# %%
series_cars.describe()
# Out:
# count      10
# unique      6
# top       Kia
# freq        2
# Name: Cars, dtype: object

# %%
type(series_cars)
# Out:
# pandas.core.series.Series

# %%
# dir(series_cars)

# %%
x = [1,2,3]
x * 2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
s = pd.Series(x)
s * 2
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %% [markdown]
# ### Data Frames

# %% [markdown]
# ## Pandas Dataframe Object
# #DataFrame as a generalized Numpy Array
# If a Series is an analog of a one-dimensional array with flexible indices, a DataFrame is an analog of a two-dimensional array with both flexible row indices and flexible column names. Just as you might think of a two-dimensional array as an ordered sequence of aligned one-dimensional columns, you can think of a DataFrame as a sequence of aligned Series objects. Here, by "aligned" we mean that they share the same index.

# %%
area_dict = {'California': 423967, 'Texas': 695662, 'New York': 141297,
             'Florida': 170312, 'Illinois': 149995}
area = pd.Series(area_dict)
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %% [markdown]
# Now that we have this along with the population Series from before, we can use a dictionary to construct a single two-dimensional object containing this information:

# %%
states = pd.DataFrame({'population': population,
                       'area': area})
states
# Out:
#             population    area
# California    38000000  423967
# Texas         26000000  695662
# New York      19000000  141297
# Florida       19000000  170312
# Illinois      12000000  149995

# %% [markdown]
# - Create dataframes from list-like objects

# %%
courses = [['601', '03', 'Mehmet', 'Sarica', 'Main'], 
           ['601', '01', 'Murat', 'Guner', 'SG'], 
           ['601', '02', 'John', 'Wan', 'Main'], 
           ['602', '01', 'Antonio', 'Diana', 'Main'], 
           ['602', '04', 'Ozgur', 'Ozturk', 'Main'], 
           ['604', '03', 'Charles', 'Givre', 'Online']]

# %%
courses_df = pd.DataFrame(courses)
courses_df
# Out:
#      0   1        2       3       4
# 0  601  03   Mehmet  Sarica    Main
# 1  601  01    Murat   Guner      SG
# 2  601  02     John     Wan    Main
# 3  602  01  Antonio   Diana    Main
# 4  602  04    Ozgur  Ozturk    Main
# 5  604  03  Charles   Givre  Online

# %%
type(courses_df[0])
# Out:
# pandas.core.series.Series

# %%
courses_df[0]
# Out:
# 0    601
# 1    601
# 2    601
# 3    602
# 4    602
# 5    604
# Name: 0, dtype: object

# %%
courses_df.loc[0]
# Out:
# 0       601
# 1        03
# 2    Mehmet
# 3    Sarica
# 4      Main
# Name: 0, dtype: object

# %% [markdown]
# - Show extra features like: column names, index etc

# %%
index = [100 ,15398, 14976, 14964, 15388, 15382]

courses_df = pd.DataFrame(courses, index = index)
courses_df
# Out:
#          0   1        2       3       4
# 100    601  03   Mehmet  Sarica    Main
# 15398  601  01    Murat   Guner      SG
# 14976  601  02     John     Wan    Main
# 14964  602  01  Antonio   Diana    Main
# 15388  602  04    Ozgur  Ozturk    Main
# 15382  604  03  Charles   Givre  Online

# %%
courses_df = pd.DataFrame(courses, 
                          index = index, 
                          columns = ['Code', 'Section', 'FirstName', 'LastName', 'Campus'])
courses_df
# Out:
#       Code Section FirstName LastName  Campus
# 100    601      03    Mehmet   Sarica    Main
# 15398  601      01     Murat    Guner      SG
# 14976  601      02      John      Wan    Main
# 14964  602      01   Antonio    Diana    Main
# 15388  602      04     Ozgur   Ozturk    Main
# 15382  604      03   Charles    Givre  Online

# %% [markdown]
# - Creating Data Frame From A Dictionary

# %%
mydictionary = {
    'names': ['Alice', 'John', 'Abby', 'Lini'],
    'Data601': [68, 74, 77, 78],
    'Data602': [84, 56, 73, 69],
    'Data603': [78, 88, 82, 87]
}


df = pd.DataFrame(mydictionary)
df
# Out:
#    names  Data601  Data602  Data603
# 0  Alice       68       84       78
# 1   John       74       56       88
# 2   Abby       77       73       82
# 3   Lini       78       69       87

# %% [markdown]
# # Part-II

# %% [markdown]
#  ## Selecting a column in a dataframe

# %%
df
# Out:
#    names  Data601  Data602  Data603
# 0  Alice       68       84       78
# 1   John       74       56       88
# 2   Abby       77       73       82
# 3   Lini       78       69       87

# %%
df['names']
# Out:
# 0    Alice
# 1     John
# 2     Abby
# 3     Lini
# Name: names, dtype: object

# %%
small_df = df[['names','Data601']]
small_df
# Out:
#    names  Data601
# 0  Alice       68
# 1   John       74
# 2   Abby       77
# 3   Lini       78

# %%
df.names
# Out:
# 0    Alice
# 1     John
# 2     Abby
# 3     Lini
# Name: names, dtype: object

# %% [markdown]
# - Accessing rows with their index

# %%
df
# Out:
#    names  Data601  Data602  Data603
# 0  Alice       68       84       78
# 1   John       74       56       88
# 2   Abby       77       73       82
# 3   Lini       78       69       87

# %%
df.loc[0]
# Out:
# names      Alice
# Data601       68
# Data602       84
# Data603       78
# Name: 0, dtype: object

# %% [markdown]
# - Accessing a value

# %%
df.loc[0, 'names']
# Out:
# 'Alice'

# %% [markdown]
# ## .loc vs .iloc

# %%
df.iloc[0, 0] # index
# Out:
# 'Alice'

# %% [markdown]
# ## Boolean Masking

# %%
df
# Out:
#    names  Data601  Data602  Data603
# 0  Alice       68       84       78
# 1   John       74       56       88
# 2   Abby       77       73       82
# 3   Lini       78       69       87

# %%
df['Data601'] > 70
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# Name: Data601, dtype: bool

# %%
greater_than_70 = df['Data601'] > 70
greater_than_70
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# Name: Data601, dtype: bool

# %%
df[greater_than_70]
# Out:
#   names  Data601  Data602  Data603
# 1  John       74       56       88
# 2  Abby       77       73       82
# 3  Lini       78       69       87

# %%
df[df['Data601'] > 70]
# Out:
#   names  Data601  Data602  Data603
# 1  John       74       56       88
# 2  Abby       77       73       82
# 3  Lini       78       69       87

# %%
# dir(df)

# %%
df.describe()
# Out:
#        Data601   Data602    Data603
# count     4.00   4.00000   4.000000
# mean     74.25  70.50000  83.750000
# std       4.50  11.56143   4.645787
# min      68.00  56.00000  78.000000
# 25%      72.50  65.75000  81.000000
# 50%      75.50  71.00000  84.500000
# 75%      77.25  75.75000  87.250000
# max      78.00  84.00000  88.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   names    4 non-null      object
#  1   Data601  4 non-null      int64
#  2   Data602  4 non-null      int64
#  3   Data603  4 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 256.0+ bytes

# %%
df['Data601'].plot()
# Out:
# <AxesSubplot:>
