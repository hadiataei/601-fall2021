# %% [markdown]
# # Data Transformations with Pandas
#
# ## Tools
#
# - Pandas Package
#
#   - Data frames vs Series
#   - Creating a dataframe and series
#   - column names and index
#   - slicing and choosing a particular row/column (loc vs iloc)
#   - Detecting missing values
#   - Creating new columns
#   - Commonly used methods: 'describe', 'info', 'head', 'tail', 'sort_values', 'count_values', etc.
#
#
# ## Concepts
#
# - Logical values and comparisons ('==', '!=', '&', '|', etc. and their combinations.)
#
# - Missing values (Difference between in pandas 'None', 'Nan', 'nan', 'null' etc.)
